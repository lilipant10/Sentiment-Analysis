# %% [markdown]
# <a href="https://colab.research.google.com/github/lilipant10/Sentiment-Analysis/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df= pd.read_csv('https://raw.githubusercontent.com/Thinkful-Ed/data-science-lectures/master/customer_feedback_null.csv')
df
# Out:
#    dept_id store_id  star_rating       state  num_employees  \
# 0     3531    M-551          4.0    Michigan            131
# 1     5473    T-323          5.0   Tennessee             59
# 2     3987    F-772          3.0     Florida             42
# 3     8723    W-834          3.0  Washington             87
# 4     9932    A-993          NaN     Arizona             95
# 5     1352    A-043          NaN      Alaska            102
# 6     4876    C-762          4.0    Colorado             68
# 7     7897    V-701          NaN     Vermont             51
# 8     2764    K-434          3.0    Kentucky             73
# 9     7324    H-101          4.0      Hawaii             50
#
#   last_name_store_manager  temp
# 0                   Patel    78
# 1                Grainger    76
# 2                     Lee    98
# 3                 Ortinez    65
# 4                Robinson    89
# 5                   Singh    42
# 6                 Del Rey    55
# 7                     Zhi    73
# ...

# %%
df.sort_values(by=['star_rating'])
# Out:
#    dept_id store_id  star_rating       state  num_employees  \
# 2     3987    F-772          3.0     Florida             42
# 3     8723    W-834          3.0  Washington             87
# 8     2764    K-434          3.0    Kentucky             73
# 0     3531    M-551          4.0    Michigan            131
# 6     4876    C-762          4.0    Colorado             68
# 9     7324    H-101          4.0      Hawaii             50
# 1     5473    T-323          5.0   Tennessee             59
# 4     9932    A-993          NaN     Arizona             95
# 5     1352    A-043          NaN      Alaska            102
# 7     7897    V-701          NaN     Vermont             51
#
#   last_name_store_manager  temp
# 2                     Lee    98
# 3                 Ortinez    65
# 8                 Iwasake    81
# 0                   Patel    78
# 6                 Del Rey    55
# 9           Stein-Brennen    79
# 1                Grainger    76
# 4                Robinson    89
# ...

# %%
df.sort_values(by=['star_rating'],ascending=False)
# Out:
#    dept_id store_id  star_rating       state  num_employees  \
# 1     5473    T-323          5.0   Tennessee             59
# 0     3531    M-551          4.0    Michigan            131
# 6     4876    C-762          4.0    Colorado             68
# 9     7324    H-101          4.0      Hawaii             50
# 2     3987    F-772          3.0     Florida             42
# 3     8723    W-834          3.0  Washington             87
# 8     2764    K-434          3.0    Kentucky             73
# 4     9932    A-993          NaN     Arizona             95
# 5     1352    A-043          NaN      Alaska            102
# 7     7897    V-701          NaN     Vermont             51
#
#   last_name_store_manager  temp
# 1                Grainger    76
# 0                   Patel    78
# 6                 Del Rey    55
# 9           Stein-Brennen    79
# 2                     Lee    98
# 3                 Ortinez    65
# 8                 Iwasake    81
# 4                Robinson    89
# ...

# %%
df.sort_values(by=['star_rating','state'])
# Out:
#    dept_id store_id  star_rating       state  num_employees  \
# 2     3987    F-772          3.0     Florida             42
# 8     2764    K-434          3.0    Kentucky             73
# 3     8723    W-834          3.0  Washington             87
# 6     4876    C-762          4.0    Colorado             68
# 9     7324    H-101          4.0      Hawaii             50
# 0     3531    M-551          4.0    Michigan            131
# 1     5473    T-323          5.0   Tennessee             59
# 5     1352    A-043          NaN      Alaska            102
# 4     9932    A-993          NaN     Arizona             95
# 7     7897    V-701          NaN     Vermont             51
#
#   last_name_store_manager  temp
# 2                     Lee    98
# 8                 Iwasake    81
# 3                 Ortinez    65
# 6                 Del Rey    55
# 9           Stein-Brennen    79
# 0                   Patel    78
# 1                Grainger    76
# 5                   Singh    42
# ...

# %%
import pandas as pd
df= pd.read_csv('https://raw.githubusercontent.com/Thinkful-Ed/data-science-lectures/master/emp_vacation_hours.csv')

# %%
df.sum()
# Out:
# emp_id                    569832
# vacation_hrs_avail         12891
# vacation_hrs_used           6004
# vacation_hrs_remaining      6887
# dtype: int64

# %%
df.count()
# Out:
# emp_id                    100
# vacation_hrs_avail        100
# vacation_hrs_used         100
# vacation_hrs_remaining    100
# dtype: int64

# %%
df.mean()
# Out:
# emp_id                    5698.32
# vacation_hrs_avail         128.91
# vacation_hrs_used           60.04
# vacation_hrs_remaining      68.87
# dtype: float64

# %%
df.median()
# Out:
# emp_id                    6253.5
# vacation_hrs_avail         135.0
# vacation_hrs_used           47.0
# vacation_hrs_remaining      61.0
# dtype: float64

# %%
df.mode()
# Out:
#     emp_id  vacation_hrs_avail  vacation_hrs_used  vacation_hrs_remaining
# 0     1014               200.0               40.0                     0.0
# 1     1129                 NaN                NaN                     NaN
# 2     1144                 NaN                NaN                     NaN
# 3     1290                 NaN                NaN                     NaN
# 4     1351                 NaN                NaN                     NaN
# ..     ...                 ...                ...                     ...
# 95    9547                 NaN                NaN                     NaN
# 96    9564                 NaN                NaN                     NaN
# 97    9645                 NaN                NaN                     NaN
# 98    9825                 NaN                NaN                     NaN
# 99    9996                 NaN                NaN                     NaN
#
# [100 rows x 4 columns]

# %%
df.min()
# Out:
# emp_id                    1014
# vacation_hrs_avail          40
# vacation_hrs_used            9
# vacation_hrs_remaining       0
# dtype: int64

# %%
df.max()
# Out:
# emp_id                    9996
# vacation_hrs_avail         200
# vacation_hrs_used          200
# vacation_hrs_remaining     191
# dtype: int64

# %%
df.std()
# Out:
# emp_id                    2706.766974
# vacation_hrs_avail          52.353325
# vacation_hrs_used           43.839911
# vacation_hrs_remaining      49.705325
# dtype: float64
